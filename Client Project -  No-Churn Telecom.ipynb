# %%
import pandas as pd
import numpy as np
import sklearn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install pymysql

# %%
import pymysql

# %%
connection = pymysql.connect(
    host='18.136.157.135',
    user='dm_team3',
    password='DM!$!Team!27@9!20&',
    database='project_telecom',
    port=3306
)

# %% [raw]
#  ## Normally, CSV files use commas (,) to separate columns,But some CSV files use other delimiters, like semicolons(;):

# %%
df = pd.read_csv('telecom.csv')

# %%
df.head()
# Out:
#   columns1;"columns2";"columns3";"columns4";"columns5";"columns6";"columns7";"columns8";"columns9";"columns10";"columns11";"columns12";"columns13";"columns14";"columns15";"columns16";"columns17";"columns18";"columns19";"columns20";"columns21"
# 0  KS;"128";"415";" 382-4657";" no";" yes";"25";"...
# 1  OH;"107";"415";" 371-7191";" no";" yes";"26";"...
# 2  NJ;"137";"415";" 358-1921";" no";" no";"0";"24...
# 3  OH;"84";"408";" 375-9999";" yes";" no";"0";"29...
# 4  OK;"75";"415";" 330-6626";" yes";" no";"0";"16...

# %% [raw]
# ## the columns in your CSV are separated by a semicolon (;).If your CSV uses semicolons, you must specify sep=';' to tell pandas how to split columns correctly.

# %%
df = pd.read_csv('telecom.csv', sep=';')

# %%
df.head()
# Out:
#   columns1  columns2  columns3   columns4 columns5 columns6  columns7  \
# 0       KS       128       415   382-4657       no      yes        25
# 1       OH       107       415   371-7191       no      yes        26
# 2       NJ       137       415   358-1921       no       no         0
# 3       OH        84       408   375-9999      yes       no         0
# 4       OK        75       415   330-6626      yes       no         0
#
#    columns8  columns9  columns10  ...  columns12  columns13  columns14  \
# 0     265.1       110      45.07  ...         99      16.78      244.7
# 1     161.6       123      27.47  ...        103      16.62      254.4
# 2     243.4       114      41.38  ...        110      10.30      162.6
# 3     299.4        71      50.90  ...         88       5.26      196.9
# 4     166.7       113      28.34  ...        122      12.61      186.9
#
#    columns15  columns16  columns17  columns18  columns19  columns20  columns21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   columns1   4617 non-null   object
#  1   columns2   4617 non-null   int64
#  2   columns3   4617 non-null   int64
#  3   columns4   4617 non-null   object
#  4   columns5   4617 non-null   object
#  5   columns6   4617 non-null   object
#  6   columns7   4617 non-null   int64
#  7   columns8   4617 non-null   float64
#  8   columns9   4617 non-null   int64
#  9   columns10  4617 non-null   float64
#  10  columns11  4617 non-null   float64
#  11  columns12  4617 non-null   int64
#  12  columns13  4617 non-null   float64
#  13  columns14  4617 non-null   float64
#  14  columns15  4617 non-null   int64
#  15  columns16  4617 non-null   float64
#  16  columns17  4617 non-null   float64
#  17  columns18  4617 non-null   int64
#  18  columns19  4617 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['columns1', 'columns2', 'columns3', 'columns4', 'columns5', 'columns6',
#        'columns7', 'columns8', 'columns9', 'columns10', 'columns11',
#        'columns12', 'columns13', 'columns14', 'columns15', 'columns16',
#        'columns17', 'columns18', 'columns19', 'columns20', 'columns21'],
#       dtype='object')

# %%
df.columns=[ 'State','Account Code','Area Code','Phone','International Plan','VMail Plan','VMail Message','Day Mins',
             'Day Calls','Day Charge','Eve Mins','Eve Calls','Eve Charge','Night Mins','Night Calls','Night Charge',
             'International Mins','International calls','International charge','CustServ Calls','Churn']

# %%
df.head()
# Out:
#   State  Account Code  Area Code      Phone International Plan VMail Plan  \
# 0    KS           128        415   382-4657                 no        yes
# 1    OH           107        415   371-7191                 no        yes
# 2    NJ           137        415   358-1921                 no         no
# 3    OH            84        408   375-9999                yes         no
# 4    OK            75        415   330-6626                yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  International Mins  International calls  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 4617 non-null   object
#  1   Account Code          4617 non-null   int64
#  2   Area Code             4617 non-null   int64
#  3   Phone                 4617 non-null   object
#  4   International Plan    4617 non-null   object
#  5   VMail Plan            4617 non-null   object
#  6   VMail Message         4617 non-null   int64
#  7   Day Mins              4617 non-null   float64
#  8   Day Calls             4617 non-null   int64
#  9   Day Charge            4617 non-null   float64
#  10  Eve Mins              4617 non-null   float64
#  11  Eve Calls             4617 non-null   int64
#  12  Eve Charge            4617 non-null   float64
#  13  Night Mins            4617 non-null   float64
#  14  Night Calls           4617 non-null   int64
# ...

# %% [markdown]
# ## Null values checking

# %%
df.isnull().sum()
# Out:
# State                   0
# Account Code            0
# Area Code               0
# Phone                   0
# International Plan      0
# VMail Plan              0
# VMail Message           0
# Day Mins                0
# Day Calls               0
# Day Charge              0
# Eve Mins                0
# Eve Calls               0
# Eve Charge              0
# Night Mins              0
# Night Calls             0
# Night Charge            0
# International Mins      0
# International calls     0
# International charge    0
# CustServ Calls          0
# Churn                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_encoded = df.copy()

# %%
object_cols = df_encoded.select_dtypes(include='object').columns
print("Object columns:", list(object_cols))
# Out:
# Object columns: ['State', 'Phone', 'International Plan', 'VMail Plan', 'Churn']

# %%
for col in object_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))

# %%
print("\nAfter encoding:")
df_encoded.info()
# Out:
# After encoding:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617 entries, 0 to 4616
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 4617 non-null   int32
#  1   Account Code          4617 non-null   int64
#  2   Area Code             4617 non-null   int64
#  3   Phone                 4617 non-null   int32
#  4   International Plan    4617 non-null   int32
#  5   VMail Plan            4617 non-null   int32
#  6   VMail Message         4617 non-null   int64
#  7   Day Mins              4617 non-null   float64
#  8   Day Calls             4617 non-null   int64
#  9   Day Charge            4617 non-null   float64
#  10  Eve Mins              4617 non-null   float64
#  11  Eve Calls             4617 non-null   int64
#  12  Eve Charge            4617 non-null   float64
#  13  Night Mins            4617 non-null   float64
# ...

# %%
df_encoded.head()
# Out:
#    State  Account Code  Area Code  Phone  International Plan  VMail Plan  \
# 0     16           128        415   2637                   0           1
# 1     35           107        415   2132                   0           1
# 2     31           137        415   1509                   0           0
# 3     35            84        408   2326                   1           0
# 4     36            75        415    150                   1           0
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
# ...

# %%
df.Churn.value_counts()
# Out:
# Churn
# False.    3961
# True.      656
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'Account Code', 'Area Code', 'Phone', 'International Plan',
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls', 'Day Charge',
#        'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins', 'Night Calls',
#        'Night Charge', 'International Mins', 'International calls',
#        'International charge', 'CustServ Calls', 'Churn'],
#       dtype='object')

# %%
corr = df.select_dtypes(include=['number']).corr()

# %%
df_encoded = df.copy()
for col in df_encoded.select_dtypes(include=['object']).columns:
    df_encoded[col] = LabelEncoder().fit_transform(df_encoded[col])

corr = df_encoded.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.hist(figsize = (10,10))
# Out:
# array([[<Axes: title={'center': 'Account Code'}>,
#         <Axes: title={'center': 'Area Code'}>,
#         <Axes: title={'center': 'VMail Message'}>,
#         <Axes: title={'center': 'Day Mins'}>],
#        [<Axes: title={'center': 'Day Calls'}>,
#         <Axes: title={'center': 'Day Charge'}>,
#         <Axes: title={'center': 'Eve Mins'}>,
#         <Axes: title={'center': 'Eve Calls'}>],
#        [<Axes: title={'center': 'Eve Charge'}>,
#         <Axes: title={'center': 'Night Mins'}>,
#         <Axes: title={'center': 'Night Calls'}>,
#         <Axes: title={'center': 'Night Charge'}>],
#        [<Axes: title={'center': 'International Mins'}>,
#         <Axes: title={'center': 'International calls'}>,
#         <Axes: title={'center': 'International charge'}>,
#         <Axes: title={'center': 'CustServ Calls'}>]], dtype=object)

# %%
sns.catplot(y = 'Churn',x = 'State',data = df.sort_values('Churn',ascending = False),kind='boxen',height = 6,aspect=3)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='State', data=df, order=df['State'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Distribution of Customers by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.show()

# %%
y = df_encoded['Churn']

# %%
x = df_encoded.drop('Churn',axis = 1)

# %% [markdown]
# ## Train a model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train_scale = scaler.fit_transform(x_train)
x_test_scale = scaler.transform(x_test)

# %%
import random
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ## LogisticRegression model

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\RAKESH\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report,confusion_matrix

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.8668831168831169
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       799
#            1       1.00      0.02      0.03       125
#
#     accuracy                           0.87       924
#    macro avg       0.93      0.51      0.48       924
# weighted avg       0.88      0.87      0.81       924
#
# [[799   0]
#  [123   2]]
# 1.0
# 0.016
# 0.031496062992125984

# %% [markdown]
# ## RandomForestClassification model

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.95995670995671
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       799
#            1       0.94      0.75      0.84       125
#
#     accuracy                           0.96       924
#    macro avg       0.95      0.87      0.91       924
# weighted avg       0.96      0.96      0.96       924
#
# [[793   6]
#  [ 31  94]]
# 0.94
# 0.752
# 0.8355555555555556

# %% [markdown]
# ## DecisionTreeClassification model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.9047619047619048
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       799
#            1       0.63      0.73      0.67       125
#
#     accuracy                           0.90       924
#    macro avg       0.79      0.83      0.81       924
# weighted avg       0.91      0.90      0.91       924
#
# [[745  54]
#  [ 34  91]]
# 0.6275862068965518
# 0.728
# 0.674074074074074

# %% [markdown]
# ## XGBClassifier model

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
xgb_pred = xgb.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(recall_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.9047619047619048
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       799
#            1       0.63      0.73      0.67       125
#
#     accuracy                           0.90       924
#    macro avg       0.79      0.83      0.81       924
# weighted avg       0.91      0.90      0.91       924
#
# [[745  54]
#  [ 34  91]]
# 0.6275862068965518
# 0.728
# 0.674074074074074

# %%
feature_importances = pd.Series(model.feature_importances_, index=x_train.columns)
sorted_importances = feature_importances.sort_values(ascending=False)

# %%
print("Top 20 most important features influencing churn:")
print(sorted_importances.head(20))
# Out:
# Top 20 most important features influencing churn:
# Day Mins                0.206618
# CustServ Calls          0.105503
# International charge    0.090164
# Eve Mins                0.083907
# International Plan      0.073592
# International calls     0.071326
# VMail Message           0.062096
# Eve Charge              0.046043
# Day Charge              0.042877
# Phone                   0.036513
# Day Calls               0.035694
# Night Mins              0.027096
# Night Charge            0.026372
# Eve Calls               0.022884
# Night Calls             0.022827
# Account Code            0.015562
# State                   0.014501
# International Mins      0.009167
# Area Code               0.005792
# VMail Plan              0.001466
# dtype: float64

# %% [markdown]
# ## Realistic Risk Scores and Flags

# %%
# Predict on full dataset
df['CHURN_RISK_SCORE'] = model.predict_proba(scaler.transform(x))[:, 1]

# Create flag column
df['CHURN_FLAG'] = df['CHURN_RISK_SCORE'].apply(lambda x: 'YES' if x > 0.5 else 'NO')

# View some results
print(df[['Churn', 'CHURN_RISK_SCORE', 'CHURN_FLAG']].head(20))
# Out:
#       Churn  CHURN_RISK_SCORE CHURN_FLAG
# 0    False.               1.0        YES
# 1    False.               1.0        YES
# 2    False.               1.0        YES
# 3    False.               1.0        YES
# 4    False.               1.0        YES
# 5    False.               1.0        YES
# 6    False.               1.0        YES
# 7    False.               1.0        YES
# 8    False.               1.0        YES
# 9    False.               1.0        YES
# 10    True.               1.0        YES
# 11   False.               1.0        YES
# 12   False.               1.0        YES
# 13   False.               1.0        YES
# 14   False.               1.0        YES
# 15    True.               0.0         NO
# 16   False.               1.0        YES
# 17   False.               1.0        YES
# 18   False.               1.0        YES
# 19   False.               1.0        YES
# ...

# %%
print(df[['Churn', 'CHURN_RISK_SCORE', 'CHURN_FLAG']].tail(10))
# Out:
#         Churn  CHURN_RISK_SCORE CHURN_FLAG
# 4607   False.               1.0        YES
# 4608   False.               1.0        YES
# 4609   False.               1.0        YES
# 4610   False.               1.0        YES
# 4611   False.               0.0         NO
# 4612   False.               1.0        YES
# 4613   False.               1.0        YES
# 4614   False.               1.0        YES
# 4615   False.               1.0        YES
# 4616   False.               1.0        YES

# %% [markdown]
# ## Visualize the Result

# %%
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,6))
plt.title("Top 10 Features Influencing Churn")
plt.bar(range(10), importances[indices][:10], align='center')
plt.xticks(range(10), x.columns[indices][:10], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Risk Score Distribution

# %%
plt.hist(df['CHURN_RISK_SCORE'], bins=20)
plt.title("Churn Risk Score Distribution")
plt.xlabel("Churn Risk Score")
plt.ylabel("Number of Customers")
plt.show()
